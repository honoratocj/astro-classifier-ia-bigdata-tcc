# %% [markdown]
# ## Autor: Claudio Honorato Junior
#
# Este trabalho faz parte da Monografia apresentada ao Departamento de Ciências de Computação do Instituto de Ciências Matemáticas e de Computação, Universidade de São Paulo - ICMC/USP, como parte dos requisitos para obtenção do título de Especialista em Inteligência Artificial e Big Data.

# %% [markdown]
# ## Classificação de Objetos Celestes e Espectros Estelares com Perceptron
#
# Este trabalho propõe o uso de Redes Neurais Multicamadas (MLP) para a classificação de
# objetos astronômicos com base em dados espectroscópicos do Sloan Digital Sky Survey (SDSS).
# A pesquisa aborda três objetivos principais: (i) classificar objetos celestes em estrelas, galáxias
# e quasares; (ii) subclassificar estrelas conforme a classificação espectral de Harvard, com base
# na temperatura superficial. O modelo MLP foi comparado com algoritmos tradicionais como
# SVM, KNN, Regressão Logística, Random Forest e Naive-Bayes, entre outros, avaliando seu desempenho por
# meio de métricas como acurácia, precisão, recall e F1-score. A metodologia incluiu limpeza,
# normalização e seleção de features espectrais, além de técnicas de validação cruzada para
# garantir a robustez dos resultados. Os achados mostram que redes neurais profundas podem
# ser eficazes na análise de espectros astronômicos, oferecendo uma alternativa promissora
# para o tratamento de grandes volumes de dados no contexto da astrofísica moderna.
#
# #### Neste notebook: (ii) subclassificar estrelas conforme a classificação espectral de Harvard
#
# ## Classification of Celestial Objects and Stellar Spectra with Perceptron
#
# This work proposes the use of Multilayer Neural Networks (MLP) for the classification of
# astronomical objects based on spectroscopic data from the Sloan Digital Sky Survey (SDSS). The
# research addresses three main objectives: (i) to classify celestial objects into stars, galaxies,
# and quasars; (ii) to subclassify stars according to the Harvard spectral classification, based on
# surface temperature. The MLP model was compared with traditional algorithms such as SVM,
# KNN, Logistic Regression, Random Forest, and Naive-Bayes, between others, evaluating its performance
# through metrics such as accuracy, precision, recall, and F1-score. The methodology included
# spectral cleaning, normalization, and feature selection, as well as cross-validation techniques
# to ensure the robustness of the results. The findings show that deep neural networks can be
# effective in the analysis of astronomical spectra, offering a promising alternative for the
# treatment of large volumes of data in the context of modern astrophysics.
#
# #### In this notebook: (ii) subclassify stars according to the Harvard spectral classification

# %% [markdown]
# ### NOTEBOOK DE TRATAMENTO E PREPARAÇÃO DOS DADOS
# #### O objetivo deste notebook é treinar os modelos e comparar para decidir o melhor, bem como salvar e armazenar os parametros utilizados.

# %%
# =========================================================
# 0. IMPORTS
# =========================================================
import multiprocessing
import os, time, joblib, numpy as np, pandas as pd
from datetime import datetime
from sklearn.model_selection import GridSearchCV, StratifiedKFold, train_test_split, RandomizedSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import (f1_score, accuracy_score,
                             precision_score, recall_score)
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, HistGradientBoostingClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.exceptions import UndefinedMetricWarning
import matplotlib.pyplot as plt

# %%
# Codigo para executar no DATABRICKS

# Definir caminhos no DBFS
base_path = "dbfs:/FileStore/classification/astronomical_objects/"
pasta_silver = f"{base_path}silver/balanceado" # f"{base_path}silver/tratado"
pasta_dataset_teste = f"{pasta_silver}/dataset_teste" 
#pasta_mdl = f"{pasta_silver}/modelos_tratado"
pasta_mdl = f"{pasta_silver}/modelos"
conjunto_de_teste = "espectros_estelares_teste"
arquivo_dados = "espectros_estelares_balanceado" # arquivo_dados = "espectros_estelares_tratado"

# Criar as pastas usando dbutils
try:
    dbutils.fs.mkdirs(pasta_silver)
    dbutils.fs.mkdirs(pasta_mdl)
    dbutils.fs.mkdirs(pasta_dataset_teste)
    print(f"Pastas criadas com sucesso em: {base_path}")
except Exception as e:
    print(f"Erro ao criar pastas: {e}")

# Verificar estrutura criada
print("\nEstrutura de pastas:")
print(f"Silver: {pasta_silver}")
print(f"Modelos (pasta_mdl): {pasta_mdl}")
print(f"Modelos (pasta_dataset_teste): {pasta_dataset_teste}")
print(f"Arquivos esperados: {arquivo_dados}, {conjunto_de_teste}")
# Out:
# Pastas criadas com sucesso em: dbfs:/FileStore/classification/astronomical_objects/
#
# Estrutura de pastas:
# Silver: dbfs:/FileStore/classification/astronomical_objects/silver/balanceado
# Modelos (pasta_mdl): dbfs:/FileStore/classification/astronomical_objects/silver/balanceado/modelos
# Modelos (pasta_dataset_teste): dbfs:/FileStore/classification/astronomical_objects/silver/balanceado/dataset_teste
# Arquivos esperados: espectros_estelares_balanceado, espectros_estelares_teste

# %%
# ------------------
# Etapa 2: Leitura dos dados com spark
# ------------------
caminho_completo = pasta_silver + "/" + arquivo_dados
print(caminho_completo)

df = spark.read.parquet(caminho_completo)

# Limitando as instancias por razoes computacionais
#df = df.limit(100000)

df_pd = df.toPandas()
# Out:
# dbfs:/FileStore/classification/astronomical_objects/silver/balanceado/espectros_estelares_balanceado

# %%
# ------------------
# Etapa 3: Preparar os dados
# ------------------
X = df_pd.drop("subclass", axis=1)           # Features
y = df_pd["subclass"]                        # Rótulo (classe)

# Dividir em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
print(X_train.shape[0])
print(X_test.shape[0])
# Out:
# 305197
# 130799

# %%
print(X_train.head(2), "\n", "---------------------------------------------")
print(y_train.head(2), "\n", "---------------------------------------------")
print(X_test.head(2), "\n", "---------------------------------------------")
print(y_test.head(2), "\n", "---------------------------------------------")
# Out:
#              r_i       g_r       u_g       i_z
# 124539  0.098584  0.223711  0.906092 -0.014015
# 271607  0.184230  0.725879  1.246999  0.221278
#  ---------------------------------------------
# 124539    A
# 271607    L
# Name: subclass, dtype: object
#  ---------------------------------------------
#              r_i       g_r       u_g       i_z
# 416090 -0.229147 -0.407070  0.096750 -0.589303
# 144191 -0.336149 -0.404757 -0.325497 -0.316052
#  ---------------------------------------------
# 416090    W
# 144191    B
# Name: subclass, dtype: object
#  ---------------------------------------------

# %%
# Separar conjunto de test para inferir em outro notebook
df_final_test = pd.concat([X_test, y_test], axis=1)

# Transformar em df spark
df_test = spark.createDataFrame(df_final_test)

# %%
caminho_completo = pasta_dataset_teste + "/" + conjunto_de_teste
print(caminho_completo)

# Salvando dados de teste separadamente
df_test.write.mode("overwrite").parquet(caminho_completo)
# Out:
# dbfs:/FileStore/classification/astronomical_objects/silver/balanceado/dataset_teste/espectros_estelares_teste

# %%
# =========================================================
# 2. PRÉ‑PROCESSAMENTO ÚNICO NO ALVO (LabelEncoder em y)
# =========================================================
le = LabelEncoder()
y_train_encoded = le.fit_transform(y_train)
y_test_encoded  = le.transform(y_test)

INPUT_LAYER_SIZE  = X_train.shape[1]
OUTPUT_LAYER_SIZE = len(np.unique(y_train_encoded))   # se precisar na Spark/MLP

# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled  = scaler.transform(X_test)

# %%
# Número total de núcleos da máquina
total_cores = multiprocessing.cpu_count()

# Regra segura: usa metade dos núcleos, no mínimo 1
safe_n_jobs = max(1, total_cores // 2)

print(f"Núcleos totais detectados: {total_cores}")
print(f"Usando n_jobs = {safe_n_jobs} (modo seguro)")
# Out:
# Núcleos totais detectados: 4
# Usando n_jobs = 2 (modo seguro)

# %%
# # =========================================================
# # 1. CONSTANTES E HIPERPARÂMETROS
# # =========================================================
CV_FOLDS = 2
RANDOM_STATE = 42
SCORING_METRIC = "f1_weighted"
N_JOBS_PARALLEL = -1
PASTA_MODELOS = pasta_mdl

# =========================================================
# Grades de hiperparâmetros para RandomizedSearch / Halving
# — cada lista contém os valores que poderão ser sorteados —
# =========================================================

# ----------- LOGISTIC REGRESSION -------------------------
# C ............. Inverso da força de regularização L2/L1.
#                 Quanto maior, menos regularização (modelo “mais livre”).
# penalty ....... Tipo de regularização (L2 = Ridge, L1 = Lasso,
#                 elasticnet = mistura entre L1 e L2).
# l1_ratio ...... Proporção L1 na elasticnet (0 = só L2, 1 = só L1).
# class_weight .. 'balanced' ajusta pesos inversamente proporcionais
#                 às frequências das classes; None = sem ajuste.
LOGREG_C          = np.logspace(-3, 2, 6)          # 0.001 → 100
LOGREG_PENALTY    = ["l2", "l1", "elasticnet"]
LOGREG_L1_RATIO   = np.linspace(0.0, 1.0, 5)       # apenas p/ elasticnet
LOGREG_CLASS_WT   = ["balanced", None]
LOGREG_MAX_ITER = 10000

# ----------- DECISION TREE -------------------------------
# max_depth ...... Profundidade máxima da árvore (None = ilimitada).
# min_samples_leaf Nº mínimo de amostras para estar numa folha —
#                  evita folhas com poucos exemplos / overfitting.
# min_samples_split Nº mínimo p/ dividir um nó.
# class_weight .... Balanceamento de classes (idem acima).
DT_MAX_DEPTH      = [None, 10, 20, 40]
DT_MIN_SAMPLES_LF = [1, 2, 4]
DT_MIN_SAMPLES_SPL= [2, 5, 10]
DT_CLASS_WT       = ["balanced", None]

# ----------- RANDOM FOREST -------------------------------
# n_estimators .... Nº de árvores no ensemble.
# max_depth ....... Profundidade máxima de cada árvore.
# max_features .... Fração ou modo de seleção de variáveis em cada split
#                   ('sqrt' = √p, 0.3 = 30 % das features etc.).
# min_samples_leaf  Idem DecisionTree.
# class_weight .... Balanceamento.
RF_N_ESTIMATORS   = [200]
RF_MAX_DEPTH      = [None]
RF_MAX_FEATURES   = ["sqrt"]
RF_MIN_SAMPLES_LF = [1]
RF_CLASS_WT       = [None]

# -------- GRADIENT BOOSTING (ou HistGradientBoosting) ----
# n_estimators .... Nº de árvores sequenciais.
# learning_rate ... Fator multiplicador de cada árvore (shrinkage).
# max_depth ....... Profundidade de cada árvore base.
# subsample ....... Fração de amostras sorteadas p/ cada árvore
#                   (<1.0 faz “stochastic gradient boosting”).
# class_weight .... Balanceamento.
GB_MAX_ITER         = [50, 100]
GB_LEARNING_RATE    = [0.05, 0.1]
GB_MAX_DEPTH        = [5, None]
GB_SUBSAMPLE        = [0.5, 0.7, 1.0]
GB_CLASS_WT         = ["balanced", None]
GB_L2_REG           = [0.0, 0.1]

# --------------------- MLP -------------------------------
# hidden_layer_sizes Tupla com o nº de neurônios em cada camada oculta
#                    (entrada/saída são inferidas automaticamente).
# alpha ............ Regularização L2 nos pesos (quanto maior, mais “suave”).
# learning_rate_init Taxa de aprendizagem inicial do otimizador Adam.
# batch_size ....... Nº de amostras por mini‑batch.
# early_stopping ... Faz split interno validação e para quando a loss pára
#                    de melhorar (evita overfitting e treino infinito).
# beta_1 / beta_2 .. Hiperparâmetros do Adam (momentum).
MLP_HIDDEN_LAYER_SIZES = [
    (128, 64, 32),
    (100, 50),
    (64, 32),
    (80, 40, 20),
    (50,),
    (64,),
]
#MLP_ALPHA         = np.logspace(-5, -2, 4)         # 1e‑5 → 1e‑2
MLP_LR_INIT       = [0.001, 0.1, 1]
MLP_BATCH_SIZE    = [256, 512]
MLP_EARLY_STOP    = [True]
MLP_BETA_1        = [0.9, 0.95]
MLP_BETA_2        = [0.999]
MLP_MAX_ITER = 10000

# # Naive Bayes
NB_VAR_SMOOTHING = np.logspace(-11, -7, 3)

# CONSTANTES – SVM
# (valores log/auto equilibrados para começar; ajuste se necessário)
#SVM_C             = np.logspace(-2, 2)    # 0.01 → 100
SVM_GAMMA         = ["auto"]           # só p/ kernel RBF
SVM_CLASS_WT      = ["balanced"]       # lida com desbalanceamento

# %%
print(INPUT_LAYER_SIZE)
print(OUTPUT_LAYER_SIZE)
# Out:
# 4
# 11

# %%
# Observações importantes
# LogisticRegression + elasticnet:

# solver="saga" é o único que aceita elasticnet no scikit-learn.

# Quando penalty != "elasticnet", o parâmetro l1_ratio é ignorado (não causa erro, mas também não influencia).

# class_weight:

# Modelos como árvore, random forest e regressão logística se beneficiam de class_weight='balanced' quando há desbalanceamento.

# MLP:

# early_stopping + batch_size + beta_1/beta_2 permitem um controle mais fino no treino.

# Dica:

# Ao usar RandomizedSearchCV, não é necessário se preocupar com combinações inválidas (ex: l1_ratio com penalty="l2"); o estimador apenas ignora.

# %%
# =========================================================
# 3. MODELOS + GRADES ATUALIZADAS (com base nas constantes)
# =========================================================

modelos_com_grid = {
    "logistic_regression": (
        LogisticRegression(
            max_iter=LOGREG_MAX_ITER,
            solver="saga",                     # necessário para L1 / elasticnet
            n_jobs=N_JOBS_PARALLEL,
            random_state=RANDOM_STATE
        ),
        {
            "clf__C":         LOGREG_C,
            "clf__penalty":   LOGREG_PENALTY,
            "clf__l1_ratio":  LOGREG_L1_RATIO,   # válido só se penalty="elasticnet"
            "clf__class_weight": LOGREG_CLASS_WT,
        },
    ),

    "decision_tree": (
        DecisionTreeClassifier(random_state=RANDOM_STATE),
        {
            "clf__max_depth":        DT_MAX_DEPTH,
            "clf__min_samples_leaf": DT_MIN_SAMPLES_LF,
            "clf__min_samples_split":DT_MIN_SAMPLES_SPL,
            "clf__class_weight":     DT_CLASS_WT,
        },
    ),

    "random_forest": (
        RandomForestClassifier(
            random_state=RANDOM_STATE,
            n_jobs=N_JOBS_PARALLEL
        ),
        {
            "clf__n_estimators":     RF_N_ESTIMATORS,
            "clf__max_depth":        RF_MAX_DEPTH,
            "clf__max_features":     RF_MAX_FEATURES,
            "clf__min_samples_leaf": RF_MIN_SAMPLES_LF,
            "clf__class_weight":     RF_CLASS_WT,
        },
    ),

    "hist_gradient_boosting": (
        HistGradientBoostingClassifier(random_state=RANDOM_STATE),
        {
            "clf__learning_rate":       GB_LEARNING_RATE,
            "clf__max_depth":           GB_MAX_DEPTH,
            "clf__max_iter":            GB_MAX_ITER,    # equivalente a n_estimators
            "clf__l2_regularization":   GB_L2_REG,
        },
    ),

    "naive_bayes": (
        GaussianNB(),
        {
            "clf__var_smoothing": NB_VAR_SMOOTHING,
        },
    ),

    "mlp": (
        MLPClassifier(
            max_iter=MLP_MAX_ITER,
            random_state=RANDOM_STATE
        ),
        {
            "clf__hidden_layer_sizes": MLP_HIDDEN_LAYER_SIZES,
            #"clf__alpha":              MLP_ALPHA,
            "clf__learning_rate_init": MLP_LR_INIT,
            "clf__batch_size":         MLP_BATCH_SIZE,
            "clf__early_stopping":     MLP_EARLY_STOP,
            "clf__beta_1":             MLP_BETA_1,
            "clf__beta_2":             MLP_BETA_2,
        },
    ),
    
    # O modelo abaixo esta desativado pois necessita de muito poder computacional para processar mais de 300 mil instancias com SVM, portanto, foi desativado.

    # "svm_rbf": (
    #     SVC(kernel="rbf", probability=False,   # probability=True = mais lento
    #         random_state=RANDOM_STATE),
    #     {
    #         #"clf__C":            SVM_C,
    #         "clf__gamma":        SVM_GAMMA,
    #         "clf__class_weight": SVM_CLASS_WT,
    #     },
    # ),
}

# %%
for nome, (est, grid) in modelos_com_grid.items():
    print("nome: ",nome)
    print("est: ",est)
    print("grid: ",grid)
    print("-------------------------")
# Out:
# nome:  logistic_regression
# est:  LogisticRegression(max_iter=10000, n_jobs=-1, random_state=42, solver='saga')
# grid:  {'clf__C': array([1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02]), 'clf__penalty': ['l2', 'l1', 'elasticnet'], 'clf__l1_ratio': array([0.  , 0.25, 0.5 , 0.75, 1.  ]), 'clf__class_weight': ['balanced', None]}
# -------------------------
# nome:  decision_tree
# est:  DecisionTreeClassifier(random_state=42)
# grid:  {'clf__max_depth': [None, 10, 20, 40], 'clf__min_samples_leaf': [1, 2, 4], 'clf__min_samples_split': [2, 5, 10], 'clf__class_weight': ['balanced', None]}
# -------------------------
# nome:  random_forest
# est:  RandomForestClassifier(n_jobs=-1, random_state=42)
# grid:  {'clf__n_estimators': [200], 'clf__max_depth': [None], 'clf__max_features': ['sqrt'], 'clf__min_samples_leaf': [1], 'clf__class_weight': [None]}
# -------------------------
# nome:  hist_gradient_boosting
# est:  HistGradientBoostingClassifier(random_state=42)
# grid:  {'clf__learning_rate': [0.05, 0.1], 'clf__max_depth': [5, None], 'clf__max_iter': [50, 100], 'clf__l2_regularization': [0.0, 0.1]}
# -------------------------
# nome:  naive_bayes
# est:  GaussianNB()
# grid:  {'clf__var_smoothing': array([1.e-11, 1.e-09, 1.e-07])}
# -------------------------
# nome:  mlp
# est:  MLPClassifier(max_iter=10000, random_state=42)
# grid:  {'clf__hidden_layer_sizes': [(128, 64, 32), (100, 50), (64, 32), (80, 40, 20), (50,), (64,)], 'clf__learning_rate_init': [0.001, 0.1, 1], 'clf__batch_size': [256, 512], 'clf__early_stopping': [True], 'clf__beta_1': [0.9, 0.95], 'clf__beta_2': [0.999]}
# -------------------------

# %%
# =========================================================
# 4. CROSS‑VALIDAÇÃO + TREINO
# =========================================================
cv_obj   = StratifiedKFold(n_splits=CV_FOLDS,
                           shuffle=True, random_state=RANDOM_STATE)
                           
# ColumnTransformer aplica StandardScaler em TODAS as colunas numéricas
preprocess = ColumnTransformer(
    [("num", StandardScaler(), list(range(INPUT_LAYER_SIZE)))],
    remainder="passthrough",
    n_jobs=N_JOBS_PARALLEL,
)

# %%
# Desativa mensagens do MLFlow e warnings
os.environ["MLFLOW_ENABLE_ARTIFACTS_PROGRESS_BAR"] = "false"
os.environ["PYTHONWARNINGS"] = "ignore::UserWarning"

# Quantidade de combinações sorteadas por modelo
N_ITER_RANDOM = 10

# DEFINIR HEADER_PER_CLASS ANTES DO LOOP
# Garante que os rótulos sejam corretos para todos os modelos
class_names = le.inverse_transform(np.unique(y_test_encoded))
header_per_class = [f"f1_{cls}" for cls in class_names]
colunas_base = ["modelo", "f1_weighted", "f1_macro", "accuracy", "precision_w", "recall_w", "tempo_s"]
df_cols = colunas_base + header_per_class

# Armazena resultados
resultados_metricas = []

for nome, (est, grid) in modelos_com_grid.items():
    print(f"\n[{datetime.now():%Y-%m-%d %H:%M:%S}] Iniciando tuning: {nome}")
    inicio = time.time()
    
    pipeline = Pipeline([
        ("prep", preprocess),
        ("clf",  est)
    ])
    
    busca = RandomizedSearchCV(
        estimator=pipeline,
        param_distributions=grid,
        n_iter=N_ITER_RANDOM,
        scoring=SCORING_METRIC,
        cv=cv_obj,
        n_jobs=N_JOBS_PARALLEL,
        random_state=RANDOM_STATE,
        refit=True,
        verbose=3,
    )
    
    # Cópias para evitar problemas de imutabilidade
    X_train_writable = np.copy(X_train)
    y_train_encoded_writable = np.copy(y_train_encoded)
    X_test_writable = np.copy(X_test)
    y_test_encoded_writable = np.copy(y_test_encoded)

    # Treina o modelo
    busca.fit(X_train_writable, y_train_encoded_writable)

    # Registra o fim do treinamento
    duracao = time.time() - inicio
    
    # ---- Salva melhor modelo ----
    caminho_modelo = os.path.join(PASTA_MODELOS, f"{nome}_best.pkl").replace("dbfs:", "/dbfs")
    joblib.dump(busca.best_estimator_, caminho_modelo)

    # ---- Avaliação no teste ----
    y_pred = busca.predict(X_test_writable)
    f1_weighted = f1_score(y_test_encoded_writable, y_pred, average="weighted")
    f1_macro    = f1_score(y_test_encoded_writable, y_pred, average="macro")
    f1_per_cl   = f1_score(y_test_encoded_writable, y_pred, average=None)
    acc  = accuracy_score(y_test_encoded_writable, y_pred)
    prec = precision_score(y_test_encoded_writable, y_pred, average="weighted", zero_division=0)
    rec  = recall_score(y_test_encoded_writable, y_pred, average="weighted", zero_division=0)
    
    print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] Modelo salvo: {caminho_modelo}")
    print(f"Tempo: {duracao:.2f}s | "
          f"F1_w: {f1_weighted:.4f} | F1_macro: {f1_macro:.4f} | "
          f"Acc: {acc:.4f} | Prec_w: {prec:.4f} | Rec_w: {rec:.4f}")
    print("F1 por classe:", np.round(f1_per_cl, 4))
    print("Melhores parâmetros:", busca.best_params_)        # melhores hiperparâmetros
    print("Melhor média da métrica na CV:", busca.best_score_)         # melhor média da métrica na CV
    print("Modelo re-treinado com X_train inteiro:", busca.best_estimator_)     # modelo re-treinado com o X_train inteiro
    
    # ---- Adiciona resultado à lista ----
    # Garante que f1_per_cl tenha o mesmo número de elementos que header_per_class
    if len(f1_per_cl) != len(header_per_class):
        print(f"AVISO: F1 por classe tem {len(f1_per_cl)} elementos, esperado {len(header_per_class)}")
        # Preenche com zeros se necessário ou trunca
        f1_per_cl_padded = np.zeros(len(header_per_class))
        f1_per_cl_padded[:min(len(f1_per_cl), len(header_per_class))] = f1_per_cl[:len(header_per_class)]
        f1_per_cl = f1_per_cl_padded
    
    # Adiciona o resultado no dataframe resultados_metricas
    resultados_metricas.append(
        [nome, f1_weighted, f1_macro, acc, prec, rec, duracao] + list(f1_per_cl)
    )
    
    # ---- Matriz de confusão ----
    cm = confusion_matrix(y_test_encoded_writable, y_pred, labels=np.arange(len(class_names)))
    # cm = confusion_matrix(y_test_encoded, y_pred, labels=np.arange(len(class_names)))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    fig, ax = plt.subplots(figsize=(10, 10))
    disp.plot(ax=ax, cmap="Blues", xticks_rotation="vertical")
    plt.title(f"Matriz de Confusão - {nome}")
    plt.tight_layout()
    plt.show()
# Out:
# [2025-07-16 02:58:03] Iniciando tuning: logistic_regression
# Fitting 2 folds for each of 10 candidates, totalling 20 fits
# /databricks/python/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1196: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# [2025-07-16 03:03:08] Modelo salvo: /dbfs/FileStore/classification/astronomical_objects/silver/balanceado/modelos/logistic_regression_best.pkl
# Tempo: 302.94s | F1_w: 0.4219 | F1_macro: 0.4216 | Acc: 0.4537 | Prec_w: 0.4101 | Rec_w: 0.4537
# F1 por classe: [0.6    0.0573 0.2711 0.2596 0.3771 0.6598 0.2301 0.8117 0.5573 0.096
#  0.7176]
# Melhores parâmetros: {'clf__penalty': 'l2', 'clf__l1_ratio': np.float64(1.0), 'clf__class_weight': 'balanced', 'clf__C': np.float64(0.01)}
# Melhor média da métrica na CV: 0.42195117984895114
# Modelo re-treinado com X_train inteiro: Pipeline(steps=[('prep',
#                  ColumnTransformer(n_jobs=-1, remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   [0, 1, 2, 3])])),
#                 ('clf',
#                  LogisticRegression(C=np.float64(0.01), class_weight='balanced',
#                                     l1_ratio=np.float64(1.0), max_iter=10000,
#                                     n_jobs=-1, random_state=42,
#                                     solver='saga'))])
# [2025-07-16 03:03:09] Iniciando tuning: decision_tree
# Fitting 2 folds for each of 10 candidates, totalling 20 fits
# [2025-07-16 03:04:04] Modelo salvo: /dbfs/FileStore/classification/astronomical_objects/silver/balanceado/modelos/decision_tree_best.pkl
# Tempo: 53.44s | F1_w: 0.8549 | F1_macro: 0.8546 | Acc: 0.8554 | Prec_w: 0.8545 | Rec_w: 0.8554
# F1 por classe: [0.8284 0.9298 0.9079 0.6232 0.8022 0.7852 0.8615 0.9131 0.9431 0.8604
#  0.946 ]
# Melhores parâmetros: {'clf__min_samples_split': 2, 'clf__min_samples_leaf': 1, 'clf__max_depth': None, 'clf__class_weight': 'balanced'}
# Melhor média da métrica na CV: 0.8096695959131479
# Modelo re-treinado com X_train inteiro: Pipeline(steps=[('prep',
#                  ColumnTransformer(n_jobs=-1, remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   [0, 1, 2, 3])])),
#                 ('clf',
#                  DecisionTreeClassifier(class_weight='balanced',
#                                         random_state=42))])
# [2025-07-16 03:04:05] Iniciando tuning: random_forest
# /databricks/python/lib/python3.12/site-packages/sklearn/model_selection/_search.py:317: UserWarning: The total space of parameters 1 is smaller than n_iter=10. Running 1 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [CV 2/2] END clf__C=0.01, clf__class_weight=balanced, clf__l1_ratio=1.0, clf__penalty=l2;, score=0.420 total time=   4.2s
# [CV 2/2] END clf__C=100.0, clf__class_weight=balanced, clf__l1_ratio=0.25, clf__penalty=l2;, score=0.420 total time=   4.5s
# [CV 1/2] END clf__C=10.0, clf__class_weight=None, clf__l1_ratio=0.75, clf__penalty=l1;, score=0.423 total time=   5.9s
# [CV 1/2] END clf__C=0.1, clf__class_weight=balanced, clf__l1_ratio=0.5, clf__penalty=elasticnet;, score=0.423 total time=  28.4s
# [CV 1/2] END clf__C=1.0, clf__class_weight=None, clf__l1_ratio=1.0, clf__penalty=l1;, score=0.423 total time= 3.7min
# [CV 1/2] END clf__class_weight=balanced, clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5;, score=0.795 total time=   6.0s
# [CV 1/2] END clf__class_weight=balanced, clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2;, score=0.809 total time=   6.1s
# [CV 1/2] END clf__class_weight=None, clf__max_depth=10, clf__min_samples_leaf=2, clf__min_samples_split=10;, score=0.637 total time=   3.0s
# [CV 1/2] END clf__class_weight=balanced, clf__max_depth=10, clf__min_samples_leaf=1, clf__min_samples_split=5;, score=0.637 total time=   3.6s
# [CV 1/2] END clf__class_weight=balanced, clf__max_depth=10, clf__min_samples_leaf=2, clf__min_samples_split=2;, score=0.637 total time=   3.2s
# [CV 1/2] END clf__class_weight=None, clf__max_depth=20, clf__min_samples_leaf=1, clf__min_samples_split=2;, score=0.795 total time=   3.1s
# [CV 2/2] END clf__C=0.001, clf__class_weight=None, clf__l1_ratio=0.25, clf__penalty=l1;, score=0.396 total time=   4.3s
# [CV 1/2] END clf__C=0.1, clf__class_weight=None, clf__l1_ratio=0.25, clf__penalty=l2;, score=0.423 total time=   4.6s
# [CV 1/2] END clf__C=0.001, clf__class_weight=None, clf__l1_ratio=0.0, clf__penalty=l2;, score=0.418 total time=   4.5s
# [CV 1/2] END clf__C=0.001, clf__class_weight=None, clf__l1_ratio=0.75, clf__penalty=l2;, score=0.418 total time=   4.2s
# [CV 1/2] END clf__C=1.0, clf__class_weight=None, clf__l1_ratio=0.5, clf__penalty=elasticnet;, score=0.423 total time= 1.1min
# [CV 2/2] END clf__class_weight=balanced, clf__max_depth=None, clf__min_samples_leaf=2, clf__min_samples_split=5;, score=0.795 total time=   6.2s
# [CV 2/2] END clf__class_weight=balanced, clf__max_depth=None, clf__min_samples_leaf=1, clf__min_samples_split=2;, score=0.810 total time=   6.1s
# [CV 2/2] END clf__class_weight=None, clf__max_depth=10, clf__min_samples_leaf=2, clf__min_samples_split=10;, score=0.638 total time=   2.9s
# [CV 2/2] END clf__class_weight=balanced, clf__max_depth=10, clf__min_samples_leaf=1, clf__min_samples_split=5;, score=0.638 total time=   3.7s
# [CV 2/2] END clf__class_weight=balanced, clf__max_depth=10, clf__min_samples_leaf=2, clf__min_samples_split=2;, score=0.638 total time=   3.3s
# [CV 2/2] END clf__class_weight=None, clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__n_estimators=200;, score=0.877 total time= 3.3min
# [CV 1/2] END clf__C=0.01, clf__class_weight=balanced, clf__l1_ratio=1.0, clf__penalty=l2;, score=0.424 total time=   4.1s
# [CV 1/2] END clf__C=100.0, clf__class_weight=balanced, clf__l1_ratio=0.25, clf__penalty=l2;, score=0.423 total time=   5.0s
# [CV 2/2] END clf__C=10.0, clf__class_weight=None, clf__l1_ratio=0.75, clf__penalty=l1;, score=0.420 total time=   5.7s
# [CV 2/2] END clf__C=0.1, clf__class_weight=balanced, clf__l1_ratio=0.5, clf__penalty=elasticnet;, score=0.420 total time=  36.8s
# [CV 2/2] END clf__C=1.0, clf__class_weight=None, clf__l1_ratio=1.0, clf__penalty=l1;, score=0.420 total time= 3.6min
# [CV 2/2] END clf__class_weight=None, clf__max_depth=20, clf__min_samples_leaf=4, clf__min_samples_split=10;, score=0.777 total time=   5.0s
# [CV 2/2] END clf__class_weight=balanced, clf__max_depth=20, clf__min_samples_leaf=1, clf__min_samples_split=2;, score=0.798 total time=   5.6s
# [CV 2/2] END clf__class_weight=balanced, clf__max_depth=40, clf__min_samples_leaf=1, clf__min_samples_split=5;, score=0.802 total time=   6.5s
# [CV 2/2] END clf__class_weight=balanced, clf__max_depth=40, clf__min_samples_leaf=4, clf__min_samples_split=5;, score=0.785 total time=   5.4s
# [2025-07-16 03:15:29] Modelo salvo: /dbfs/FileStore/classification/astronomical_objects/silver/balanceado/modelos/random_forest_best.pkl
# Tempo: 664.93s | F1_w: 0.9104 | F1_macro: 0.9102 | Acc: 0.9115 | Prec_w: 0.9104 | Rec_w: 0.9115
# F1 por classe: [0.8954 0.9623 0.9517 0.7374 0.88   0.8561 0.926  0.9424 0.9697 0.9231
#  0.9686]
# Melhores parâmetros: {'clf__n_estimators': 200, 'clf__min_samples_leaf': 1, 'clf__max_features': 'sqrt', 'clf__max_depth': None, 'clf__class_weight': None}
# Melhor média da métrica na CV: 0.876647895841483
# Modelo re-treinado com X_train inteiro: Pipeline(steps=[('prep',
#                  ColumnTransformer(n_jobs=-1, remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   [0, 1, 2, 3])])),
#                 ('clf',
#                  RandomForestClassifier(n_estimators=200, n_jobs=-1,
#                                         random_state=42))])
# [2025-07-16 03:15:30] Iniciando tuning: hist_gradient_boosting
# Fitting 2 folds for each of 10 candidates, totalling 20 fits
# [2025-07-16 03:22:57] Modelo salvo: /dbfs/FileStore/classification/astronomical_objects/silver/balanceado/modelos/hist_gradient_boosting_best.pkl
# Tempo: 434.43s | F1_w: 0.7442 | F1_macro: 0.7437 | Acc: 0.7471 | Prec_w: 0.7473 | Rec_w: 0.7471
# F1 por classe: [0.736  0.7905 0.7302 0.4668 0.685  0.7948 0.6656 0.9003 0.8746 0.6268
#  0.9103]
# Melhores parâmetros: {'clf__max_iter': 100, 'clf__max_depth': None, 'clf__learning_rate': 0.1, 'clf__l2_regularization': 0.1}
# Melhor média da métrica na CV: 0.7377158768631078
# Modelo re-treinado com X_train inteiro: Pipeline(steps=[('prep',
#                  ColumnTransformer(n_jobs=-1, remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   [0, 1, 2, 3])])),
#                 ('clf',
#                  HistGradientBoostingClassifier(l2_regularization=0.1,
#                                                 random_state=42))])
# [2025-07-16 03:22:57] Iniciando tuning: naive_bayes
# /databricks/python/lib/python3.12/site-packages/sklearn/model_selection/_search.py:317: UserWarning: The total space of parameters 3 is smaller than n_iter=10. Running 3 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# [2025-07-16 03:23:20] Modelo salvo: /dbfs/FileStore/classification/astronomical_objects/silver/balanceado/modelos/naive_bayes_best.pkl
# Tempo: 20.75s | F1_w: 0.2741 | F1_macro: 0.2745 | Acc: 0.3705 | Prec_w: 0.3025 | Rec_w: 0.3705
# F1 por classe: [0.5105 0.0876 0.0539 0.355  0.0088 0.5711 0.217  0.669  0.0143 0.0043
#  0.5281]
# Melhores parâmetros: {'clf__var_smoothing': np.float64(1e-11)}
# Melhor média da métrica na CV: 0.2768247796323934
# Modelo re-treinado com X_train inteiro: Pipeline(steps=[('prep',
#                  ColumnTransformer(n_jobs=-1, remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   [0, 1, 2, 3])])),
#                 ('clf', GaussianNB(var_smoothing=np.float64(1e-11)))])
# [2025-07-16 03:23:21] Iniciando tuning: mlp
# Fitting 2 folds for each of 10 candidates, totalling 20 fits
# [CV 1/2] END clf__C=0.001, clf__class_weight=None, clf__l1_ratio=0.25, clf__penalty=l1;, score=0.403 total time=   5.1s
# [CV 2/2] END clf__C=0.1, clf__class_weight=None, clf__l1_ratio=0.25, clf__penalty=l2;, score=0.420 total time=   4.5s
# [CV 2/2] END clf__C=0.001, clf__class_weight=None, clf__l1_ratio=0.0, clf__penalty=l2;, score=0.410 total time=   4.8s
# [CV 2/2] END clf__C=0.001, clf__class_weight=None, clf__l1_ratio=0.75, clf__penalty=l2;, score=0.410 total time=   4.2s
# [CV 2/2] END clf__C=1.0, clf__class_weight=None, clf__l1_ratio=0.5, clf__penalty=elasticnet;, score=0.420 total time= 1.2min
# [CV 1/2] END clf__class_weight=None, clf__max_depth=20, clf__min_samples_leaf=4, clf__min_samples_split=10;, score=0.776 total time=   5.0s
# [CV 1/2] END clf__class_weight=balanced, clf__max_depth=20, clf__min_samples_leaf=1, clf__min_samples_split=2;, score=0.795 total time=   5.2s
# [CV 1/2] END clf__class_weight=balanced, clf__max_depth=40, clf__min_samples_leaf=1, clf__min_samples_split=5;, score=0.801 total time=   6.3s
# [CV 1/2] END clf__class_weight=balanced, clf__max_depth=40, clf__min_samples_leaf=4, clf__min_samples_split=5;, score=0.786 total time=   5.4s
# [CV 2/2] END clf__class_weight=None, clf__max_depth=20, clf__min_samples_leaf=1, clf__min_samples_split=2;, score=0.798 total time=   3.3s
# [CV 1/2] END clf__class_weight=None, clf__max_depth=None, clf__max_features=sqrt, clf__min_samples_leaf=1, clf__n_estimators=200;, score=0.877 total time= 3.3min
# [CV 2/2] END clf__l2_regularization=0.0, clf__learning_rate=0.05, clf__max_depth=5, clf__max_iter=50;, score=0.621 total time=  35.5s
# [CV 1/2] END clf__l2_regularization=0.0, clf__learning_rate=0.1, clf__max_depth=5, clf__max_iter=100;, score=0.692 total time= 1.2min
# [CV 1/2] END clf__l2_regularization=0.1, clf__learning_rate=0.1, clf__max_depth=5, clf__max_iter=100;, score=0.694 total time= 1.1min
# [CV 1/2] END clf__l2_regularization=0.1, clf__learning_rate=0.05, clf__max_depth=5, clf__max_iter=50;, score=0.623 total time=  34.5s
# [CV 1/2] END clf__l2_regularization=0.0, clf__learning_rate=0.05, clf__max_depth=None, clf__max_iter=50;, score=0.669 total time=  34.8s
# [CV 1/2] END clf__l2_regularization=0.1, clf__learning_rate=0.1, clf__max_depth=None, clf__max_iter=100;, score=0.739 total time=  46.6s
# [CV 2/2] END ..........clf__var_smoothing=1e-09;, score=0.277 total time=   0.4s
# [CV 1/2] END clf__batch_size=512, clf__beta_1=0.95, clf__beta_2=0.999, clf__early_stopping=True, clf__hidden_layer_sizes=(64, 32), clf__learning_rate_init=1;, score=0.015 total time=  19.5s
# [CV 2/2] END clf__batch_size=256, clf__beta_1=0.95, clf__beta_2=0.999, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate_init=0.001;, score=0.669 total time= 7.3min
# [CV 2/2] END clf__batch_size=256, clf__beta_1=0.9, clf__beta_2=0.999, clf__early_stopping=True, clf__hidden_layer_sizes=(50,), clf__learning_rate_init=0.001;, score=0.566 total time= 1.2min
# [CV 1/2] END clf__l2_regularization=0.0, clf__learning_rate=0.05, clf__max_depth=5, clf__max_iter=50;, score=0.622 total time=  35.2s
# [CV 2/2] END clf__l2_regularization=0.0, clf__learning_rate=0.1, clf__max_depth=5, clf__max_iter=100;, score=0.687 total time= 1.2min
# [CV 2/2] END clf__l2_regularization=0.1, clf__learning_rate=0.1, clf__max_depth=5, clf__max_iter=100;, score=0.690 total time= 1.1min
# [CV 2/2] END clf__l2_regularization=0.1, clf__learning_rate=0.05, clf__max_depth=5, clf__max_iter=50;, score=0.621 total time=  35.6s
# [CV 2/2] END clf__l2_regularization=0.0, clf__learning_rate=0.05, clf__max_depth=None, clf__max_iter=50;, score=0.666 total time=  35.2s
# [CV 2/2] END clf__l2_regularization=0.1, clf__learning_rate=0.1, clf__max_depth=None, clf__max_iter=100;, score=0.736 total time=  45.2s
# [CV 1/2] END ..........clf__var_smoothing=1e-11;, score=0.277 total time=   0.3s
# [CV 2/2] END ..........clf__var_smoothing=1e-07;, score=0.277 total time=   0.2s
# [CV 2/2] END clf__batch_size=512, clf__beta_1=0.95, clf__beta_2=0.999, clf__early_stopping=True, clf__hidden_layer_sizes=(64, 32), clf__learning_rate_init=1;, score=0.015 total time=  15.1s
# [CV 1/2] END clf__batch_size=256, clf__beta_1=0.95, clf__beta_2=0.999, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate_init=0.001;, score=0.642 total time= 2.7min
# [CV 1/2] END clf__batch_size=256, clf__beta_1=0.95, clf__beta_2=0.999, clf__early_stopping=True, clf__hidden_layer_sizes=(80, 40, 20), clf__learning_rate_init=0.1;, score=0.527 total time=  30.8s
# [CV 2/2] END clf__batch_size=256, clf__beta_1=0.95, clf__beta_2=0.999, clf__early_stopping=True, clf__hidden_layer_sizes=(80, 40, 20), clf__learning_rate_init=0.1;, score=0.534 total time=  40.4s
# [CV 1/2] END clf__batch_size=512, clf__beta_1=0.9, clf__beta_2=0.999, clf__early_stopping=True, clf__hidden_layer_sizes=(50,), clf__learning_rate_init=1;, score=0.328 total time=  14.7s
# [CV 2/2] END clf__batch_size=512, clf__beta_1=0.9, clf__beta_2=0.999, clf__early_stopping=True, clf__hidden_layer_sizes=(50,), clf__learning_rate_init=1;, score=0.192 total time=  10.7s
# [CV 1/2] END clf__batch_size=256, clf__beta_1=0.9, clf__beta_2=0.999, clf__early_stopping=True, clf__hidden_layer_sizes=(80, 40, 20), clf__learning_rate_init=0.1;, score=0.491 total time=  28.2s
# [CV 2/2] END clf__batch_size=256, clf__beta_1=0.9, clf__beta_2=0.999, clf__early_stopping=True, clf__hidden_layer_sizes=(80, 40, 20), clf__learning_rate_init=0.1;, score=0.540 total time=  38.8s
# [CV 1/2] END clf__batch_size=256, clf__beta_1=0.95, clf__beta_2=0.999, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate_init=0.1;, score=0.543 total time=  20.0s
# [CV 2/2] END clf__batch_size=256, clf__beta_1=0.95, clf__beta_2=0.999, clf__early_stopping=True, clf__hidden_layer_sizes=(64,), clf__learning_rate_init=0.1;, score=0.547 total time=  35.3s
# [CV 1/2] END clf__batch_size=256, clf__beta_1=0.9, clf__beta_2=0.999, clf__early_stopping=True, clf__hidden_layer_sizes=(50,), clf__learning_rate_init=0.001;, score=0.573 total time= 1.2min
# [CV 1/2] END clf__batch_size=512, clf__beta_1=0.95, clf__beta_2=0.999, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate_init=0.001;, score=0.644 total time= 2.6min
# [CV 1/2] END clf__l2_regularization=0.0, clf__learning_rate=0.05, clf__max_depth=5, clf__max_iter=100;, score=0.655 total time= 1.2min
# [CV 2/2] END clf__l2_regularization=0.1, clf__learning_rate=0.1, clf__max_depth=None, clf__max_iter=50;, score=0.696 total time=  36.3s
# [CV 2/2] END clf__l2_regularization=0.1, clf__learning_rate=0.05, clf__max_depth=None, clf__max_iter=100;, score=0.695 total time= 1.2min
# [CV 2/2] END clf__l2_regularization=0.1, clf__learning_rate=0.05, clf__max_depth=5, clf__max_iter=100;, score=0.650 total time= 1.2min
# [CV 1/2] END ..........clf__var_smoothing=1e-09;, score=0.277 total time=   0.4s
# [CV 2/2] END clf__batch_size=256, clf__beta_1=0.9, clf__beta_2=0.999, clf__early_stopping=True, clf__hidden_layer_sizes=(100, 50), clf__learning_rate_init=0.1;, score=0.555 total time=  32.6s
# [CV 1/2] END clf__batch_size=256, clf__beta_1=0.9, clf__beta_2=0.999, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate_init=0.001;, score=0.668 total time= 7.7min
# [CV 2/2] END clf__batch_size=512, clf__beta_1=0.95, clf__beta_2=0.999, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate_init=0.001;, score=0.677 total time= 7.6min
# [CV 2/2] END clf__l2_regularization=0.0, clf__learning_rate=0.05, clf__max_depth=5, clf__max_iter=100;, score=0.650 total time= 1.2min
# [CV 1/2] END clf__l2_regularization=0.1, clf__learning_rate=0.1, clf__max_depth=None, clf__max_iter=50;, score=0.700 total time=  34.9s
# [CV 1/2] END clf__l2_regularization=0.1, clf__learning_rate=0.05, clf__max_depth=None, clf__max_iter=100;, score=0.697 total time= 1.1min
# [CV 1/2] END clf__l2_regularization=0.1, clf__learning_rate=0.05, clf__max_depth=5, clf__max_iter=100;, score=0.656 total time= 1.2min
# [CV 2/2] END ..........clf__var_smoothing=1e-11;, score=0.277 total time=   0.4s
# [CV 1/2] END ..........clf__var_smoothing=1e-07;, score=0.277 total time=   0.2s
# [CV 1/2] END clf__batch_size=256, clf__beta_1=0.9, clf__beta_2=0.999, clf__early_stopping=True, clf__hidden_layer_sizes=(100, 50), clf__learning_rate_init=0.1;, score=0.547 total time=  58.6s
# [CV 2/2] END clf__batch_size=256, clf__beta_1=0.9, clf__beta_2=0.999, clf__early_stopping=True, clf__hidden_layer_sizes=(128, 64, 32), clf__learning_rate_init=0.001;, score=0.688 total time=14.3min
# [2025-07-16 04:00:31] Modelo salvo: /dbfs/FileStore/classification/astronomical_objects/silver/balanceado/modelos/mlp_best.pkl
# Tempo: 2227.48s | F1_w: 0.7031 | F1_macro: 0.7026 | Acc: 0.7068 | Prec_w: 0.7043 | Rec_w: 0.7068
# F1 por classe: [0.6984 0.7171 0.6901 0.4213 0.6495 0.7836 0.6079 0.8945 0.8258 0.5542
#  0.8864]
# Melhores parâmetros: {'clf__learning_rate_init': 0.001, 'clf__hidden_layer_sizes': (128, 64, 32), 'clf__early_stopping': True, 'clf__beta_2': 0.999, 'clf__beta_1': 0.9, 'clf__batch_size': 256}
# Melhor média da métrica na CV: 0.6783789658847985
# Modelo re-treinado com X_train inteiro: Pipeline(steps=[('prep',
#                  ColumnTransformer(n_jobs=-1, remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   [0, 1, 2, 3])])),
#                 ('clf',
#                  MLPClassifier(batch_size=256, early_stopping=True,
#                                hidden_layer_sizes=(128, 64, 32), max_iter=10000,
#                                random_state=42))])

# %%
# ---- GERAÇÃO DO DATAFRAME FINAL COM TODAS AS MÉTRICAS ----
df_result = pd.DataFrame(resultados_metricas, columns=df_cols)

# Ordenar em ordem decrescente
df_result = df_result.sort_values("f1_weighted", ascending=False)

# Arredondar valores numéricos para 4 casas decimais
colunas_numericas = df_result.select_dtypes(include=[np.number]).columns
df_result[colunas_numericas] = df_result[colunas_numericas].round(4)  # coloque 2 se quiser duas casas

display(df_result)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>modelo</th><th>f1_weighted</th><th>f1_macro</th><th>accuracy</th><th>precision_w</th><th>recall_w</th><th>tempo_s</th><th>f1_A</th><th>f1_B</th><th>f1_C</th><th>f1_F</th><th>f1_G</th><th>f1_K</th><th>f1_L</th><th>f1_M</th><th>f1_O</th><th>f1_T</th><th>f1_W</th></tr></thead><tbody><tr><td>random_forest</td><td>0.9104</td><td>0.9102</td><td>0.9115</td><td>0.9104</td><td>0.9115</td><td>664.9285</td><td>0.8954</td><td>0.9623</td><td>0.9517</td><td>0.7374</td><td>0.88</td><td>0.8561</td><td>0.926</td><td>0.9424</td><td>0.9697</td><td>0.9231</td><td>0.9686</td></tr><tr><td>decision_tree</td><td>0.8549</td><td>0.8546</td><td>0.8554</td><td>0.8545</td><td>0.8554</td><td>53.4449</td><td>0.8284</td><td>0.9298</td><td>0.9079</td><td>0.6232</td><td>0.8022</td><td>0.7852</td><td>0.8615</td><td>0.9131</td><td>0.9431</td><td>0.8604</td><td>0.946</td></tr><tr><td>hist_gradient_boosting</td><td>0.7442</td><td>0.7437</td><td>0.7471</td><td>0.7473</td><td>0.7471</td><td>434.4309</td><td>0.736</td><td>0.7905</td><td>0.7302</td><td>0.4668</td><td>0.685</td><td>0.7948</td><td>0.6656</td><td>0.9003</td><td>0.8746</td><td>0.6268</td><td>0.9103</td></tr><tr><td>mlp</td><td>0.7031</td><td>0.7026</td><td>0.7068</td><td>0.7043</td><td>0.7068</td><td>2227.4774</td><td>0.6984</td><td>0.7171</td><td>0.6901</td><td>0.4213</td><td>0.6495</td><td>0.7836</td><td>0.6079</td><td>0.8945</td><td>0.8258</td><td>0.5542</td><td>0.8864</td></tr><tr><td>logistic_regression</td><td>0.4219</td><td>0.4216</td><td>0.4537</td><td>0.4101</td><td>0.4537</td><td>302.9388</td><td>0.6</td><td>0.0573</td><td>0.2711</td><td>0.2596</td><td>0.3771</td><td>0.6598</td><td>0.2301</td><td>0.8117</td><td>0.5573</td><td>0.096</td><td>0.7176</td></tr><tr><td>naive_bayes</td><td>0.2741</td><td>0.2745</td><td>0.3705</td><td>0.3025</td><td>0.3705</td><td>20.7464</td><td>0.5105</td><td>0.0876</td><td>0.0539</td><td>0.355</td><td>0.0088</td><td>0.5711</td><td>0.217</td><td>0.669</td><td>0.0143</td><td>0.0043</td><td>0.5281</td></tr></tbody></table></div>
